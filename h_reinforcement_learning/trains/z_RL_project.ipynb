# %% [markdown]
# #Reinforcement Learning for Algorithmic Trading
#
#
# In this project, you will implement an algorithmic trading bot using reinforcement learning, specifically employing the actor-critic method with policy gradients. The primary goal is to develop a bot that can make profitable trading decisions by learning from historical financial data. The actor-critic architecture combines two neural networks: the actor, which decides the actions, and the critic, which evaluates those actions. We use simple multi-layer perceptrons (MLPs) for both networks, but in practice, recurrent networks (RNNs) are often preferred for their ability to handle time-series data more effectively.
#
# You will be working with the gym-trading-env package to simulate a trading environment. This environment provides various trading-related observations and actions, enabling the bot to learn and adapt its strategies. For more details, refer to the [documentation](https://gym-trading-env.readthedocs.io/en/latest/index.html) of the trading environment.
#
# While this project focuses on a simplified implementation, it serves as a foundational step toward solving more complex, practical problems. Even if the final trading bot does not perform optimally, the experience gained from working with reinforcement learning algorithms and trading environments is invaluable. It introduces you to crucial tools and concepts that are widely used in both academic research and industry applications.

# %%
# !pip install gym-trading-env
# Out:
# Requirement already satisfied: gym-trading-env in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (0.3.5)
# Requirement already satisfied: pandas>=1.5.3 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from gym-trading-env) (2.2.3)
# Requirement already satisfied: numpy>=1.21.1 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from gym-trading-env) (2.2.5)
# Requirement already satisfied: gymnasium>=0.28.1 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from gym-trading-env) (1.1.0)
# Requirement already satisfied: flask==2.2.5 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from gym-trading-env) (2.2.5)
# Requirement already satisfied: pyecharts>=2.0.2 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from gym-trading-env) (2.0.8)
# Requirement already satisfied: ccxt==3.0.59 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from gym-trading-env) (3.0.59)
# Requirement already satisfied: nest_asyncio in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from gym-trading-env) (1.6.0)
# Requirement already satisfied: setuptools>=60.9.0 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from ccxt==3.0.59->gym-trading-env) (80.8.0)
# Requirement already satisfied: certifi>=2018.1.18 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from ccxt==3.0.59->gym-trading-env) (2025.4.26)
# Requirement already satisfied: requests>=2.18.4 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from ccxt==3.0.59->gym-trading-env) (2.32.3)
# Requirement already satisfied: cryptography>=2.6.1 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from ccxt==3.0.59->gym-trading-env) (45.0.3)
# Requirement already satisfied: aiohttp>=3.8 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from ccxt==3.0.59->gym-trading-env) (3.12.2)
# Requirement already satisfied: aiodns>=1.1.1 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from ccxt==3.0.59->gym-trading-env) (3.4.0)
# Requirement already satisfied: yarl>=1.7.2 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from ccxt==3.0.59->gym-trading-env) (1.20.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from flask==2.2.5->gym-trading-env) (3.1.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from flask==2.2.5->gym-trading-env) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from flask==2.2.5->gym-trading-env) (2.2.0)
# Requirement already satisfied: click>=8.0 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from flask==2.2.5->gym-trading-env) (8.2.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from gymnasium>=0.28.1->gym-trading-env) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from gymnasium>=0.28.1->gym-trading-env) (4.13.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from gymnasium>=0.28.1->gym-trading-env) (0.0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from pandas>=1.5.3->gym-trading-env) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from pandas>=1.5.3->gym-trading-env) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from pandas>=1.5.3->gym-trading-env) (2025.2)
# Requirement already satisfied: prettytable in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from pyecharts>=2.0.2->gym-trading-env) (3.16.0)
# Requirement already satisfied: simplejson in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from pyecharts>=2.0.2->gym-trading-env) (3.20.1)
# Requirement already satisfied: pycares>=4.0.0 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from aiodns>=1.1.1->ccxt==3.0.59->gym-trading-env) (4.8.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from aiohttp>=3.8->ccxt==3.0.59->gym-trading-env) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from aiohttp>=3.8->ccxt==3.0.59->gym-trading-env) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from aiohttp>=3.8->ccxt==3.0.59->gym-trading-env) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from aiohttp>=3.8->ccxt==3.0.59->gym-trading-env) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from aiohttp>=3.8->ccxt==3.0.59->gym-trading-env) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from aiohttp>=3.8->ccxt==3.0.59->gym-trading-env) (0.3.1)
# Requirement already satisfied: colorama in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from click>=8.0->flask==2.2.5->gym-trading-env) (0.4.6)
# Requirement already satisfied: cffi>=1.14 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from cryptography>=2.6.1->ccxt==3.0.59->gym-trading-env) (1.17.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from Jinja2>=3.0->flask==2.2.5->gym-trading-env) (3.0.2)
# Requirement already satisfied: six>=1.5 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.5.3->gym-trading-env) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from requests>=2.18.4->ccxt==3.0.59->gym-trading-env) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from requests>=2.18.4->ccxt==3.0.59->gym-trading-env) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from requests>=2.18.4->ccxt==3.0.59->gym-trading-env) (2.4.0)
# Requirement already satisfied: wcwidth in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from prettytable->pyecharts>=2.0.2->gym-trading-env) (0.2.13)
# Requirement already satisfied: pycparser in c:\users\beta\documents\0-academy-hamrah\h_reinforcement_learning\trains\venv_rl\lib\site-packages (from cffi>=1.14->cryptography>=2.6.1->ccxt==3.0.59->gym-trading-env) (2.22)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch
from torch import nn
import numpy as np
from matplotlib import pyplot as plt

class Actor(nn.Module):
    def __init__(self, input_dim, output_dim=1, hidden_dim=32):
        super(Actor, self).__init__()

        '''
        TODO: Initialize layers for the actor network.
        Use nn.Linear for linear layers and nn.ReLU for activation.
        '''
        
        layer1 = nn.Linear(input_dim , hidden_dim , bias=True)
        relu = nn.ReLU()
        layer2 = nn.Linear(hidden_dim , output_dim , bias=True)
        self.estimator = nn.Sequential(layer1 , relu , layer2)


    def forward(self, state):

        '''
        TODO: Convert the input state to a torch tensor if it is not already,
        and pass it through the sequential model to get the prediction.
        '''


        return pred


class Critic(nn.Module):
    def __init__(self, input_dim, output_dim=1, hidden_dim=32):
        super(Critic, self).__init__()

        '''
        TODO: Initialize layers for the critic network.
        Use nn.Linear for linear layers and nn.ReLU for activation.
        '''


    def forward(self, state):
        '''
        TODO: Convert the input state to a torch tensor if it is not already,
        and pass it through the model to get the value prediction.
        '''


        return v_pred

# %%
class PG_Agent:
    def __init__(self, state_size, action_size, learning_rate=0.001, discount_factor=0.98):
        self.state_size = state_size
        self.action_size = action_size
        self.discount_factor = discount_factor

        '''
        TODO: Initialize the actor and critic networks with state_size and action_size.
        '''


        '''
        TODO: Initialize the loss function and optimizers for the actor and critic networks using torch.optim.Adam.
        '''


    def sample_action(self, state):

        '''
        TODO:
        Get action probabilities from the actor network, apply softmax,
        and sample an action based on the probabilities.
        '''

        return action

    def calc_reward_to_go(self, rewards):
        '''
        TODO: Calculate discounted future rewards.
        Initialize a running sum and iterate through rewards in reverse to compute rewards-to-go.
        '''


        return rewards2go


    def update(self, states, actions, rewards, max_batch=512):
        # Process batch if needed
        if len(states) > max_batch:
            st_ind = np.random.choice(len(states) - max_batch, 1).item()
            end_ind = st_ind + max_batch
            actions = actions[st_ind: end_ind]
            rewards = rewards[st_ind: end_ind]
            states = states[st_ind: end_ind]

        actions = torch.tensor(actions)
        rewards2go = self.calc_reward_to_go(rewards)
        rewards2go = torch.tensor(rewards2go)

        # Update Critic network
        '''
        TODO: Zero the gradients, perform a forward pass to get values, compute the loss,
        and perform backward pass and optimization step for the critic network.
        '''


        # Update Actor network
        '''
        TODO: Zero the gradients, perform a forward pass to get logits,
        compute the advantages, log probabilities, actor loss, and perform backward pass and optimization step for the actor network.
        '''

# %%
from gym_trading_env.downloader import download
import datetime
import os

data_dir = 'data'
os.makedirs(data_dir, exist_ok=True)

# Download and prepare your data
# Fetch historical BTC/USDT data from the Bitfinex exchange
# Timeframe is set to 1 hour and data is saved in the 'data' directory
# Data collection starts from January 1, 2021

download(exchange_names=["bitfinex2"], symbols=["BTC/USDT"], timeframe="1h", dir="data",
         since=datetime.datetime(year=2021, month=1, day=1))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from gym_trading_env.downloader import download
#       2 import datetime
#       3 import os
#
# ModuleNotFoundError: No module named 'gym_trading_env'

# %%
import gymnasium as gym
import pandas as pd
from tqdm import tqdm
import os

# Load dataset
df = pd.read_pickle("./data/bitfinex2-BTCUSDT-1h.pkl")

# Create features for the trading environment
df["feature_pct_change"] = df["close"].pct_change()
df["feature_high"] = df["high"] / df["close"] - 1
df["feature_low"] = df["low"] / df["close"] - 1
df.dropna(inplace=True)


# Initialize the trading environment
env = gym.make("TradingEnv",
        name= "BTCUSD",
        df = df, # Your dataset with your custom features
        positions = [ -1, 0, 1], # -1 (=SHORT), 0(=OUT), +1 (=LONG)
        trading_fees = 0.01/100, # 0.01% per stock buy / sell (Binance fees)
        borrow_interest_rate = 0.0003/100, # 0.0003% per timestep (one timestep = 1h here)
        windows = 20) # Past N observations

obs_dim = env.observation_space.shape[0] * env.observation_space.shape[1]
# Initialize the policy gradient agent
agent = PG_Agent(obs_dim, env.action_space.n)

n_episodes = 500
total_reward = []

for i in tqdm(range(n_episodes)):
    state, info = env.reset()

    episode_states = []
    episode_rewards = []
    episode_actions = []

    done, truncated = False, False
    max_steps = 10000 # Maximum number of steps per episode
    step = 0
    while not done and not truncated and step < max_steps:

        '''
        TODO: Flatten the state for the agent, sample an action from the policy,
        interact with the environment using the sampled action,
        and store the state, action, and reward.
        '''


        state = next_state
        step += 1

    # Update the agent after the episode
    agent.update(np.array(episode_states), np.array(episode_actions), episode_rewards)
    total_reward.append(np.sum(episode_rewards))

# Plot the smoothed total rewards over episodes
plt.plot(np.convolve(total_reward, np.ones(20) / 20)[10: -10])
plt.title('Smoothed Rewards')
plt.show()
