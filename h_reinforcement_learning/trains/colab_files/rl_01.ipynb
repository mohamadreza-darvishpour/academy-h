# %%
# !pip install gymnasium==1.1.0
# !pip install numpy==2.2.5
# !pip install gym==0.26.0

# %%
import gymnasium as gym
from gym.wrappers import RecordVideo
import os
from IPython.display import HTML
from base64 import b64encode

video_folder = './rl_vids'

#make video savable env
env = gym.make('CartPole-v1',render_mode='rgb_array')
env = RecordVideo(env , video_folder , episode_trigger=lambda x : True)


#reset env
state , _ = env.reset()

while True:
  action = env.action_space.sample()

  next_obs , reward , terminated , truncated , info = env.step(action)

  if terminated or truncated :
    break

env.close()
# Out:
# /usr/local/lib/python3.11/dist-packages/gym/wrappers/record_video.py:75: UserWarning: WARN: Overwriting existing videos at /content/rl_vids folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Moviepy - Building video /content/rl_vids/rl-video-episode-0.mp4.
# Moviepy - Writing video /content/rl_vids/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /content/rl_vids/rl-video-episode-0.mp4

# %%
#get and show the video.


# پیدا کردن مسیر ویدیوی ذخیره‌شده
video_path = None
for root, dirs, files in os.walk(video_folder):
    for file in files:
        if file.endswith('.mp4'):
          video_path = os.path.join(root, file)

def show_video(video_path):
  if video_path:
    mp4 = open(video_path , 'rb' ).read()
    data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
    return HTML(f"""
    <video width=640 controls>
              <source src="{data_url}" type="video/mp4">
        </video>
    """)
  else :
    return HTML("<p><b>ویدیو یافت نشد!</b></p>")

show_video(video_path)
# Out:
#     <video width=640 controls>
#               <source src="data:video/mp4;base64,..." type="video/mp4">
#         </video>
